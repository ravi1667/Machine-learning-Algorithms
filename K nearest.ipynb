# %%
import pandas as pd

# %%
df=pd.read_csv('insurance.csv')

# %%
df
# Out:
#       age  sex     bmi  children  smoker      charges
# 0      19    0  27.900         0       0  16884.92400
# 1      18    1  33.770         1       1   1725.55230
# 2      28    1  33.000         3       1   4449.46200
# 3      33    1  22.705         0       1  21984.47061
# 4      32    1  28.880         0       1   3866.85520
# ...   ...  ...     ...       ...     ...          ...
# 1333   50    1  30.970         3       1  10600.54830
# 1334   18    0  31.920         0       1   2205.98080
# 1335   18    0  36.850         0       1   1629.83350
# 1336   21    0  25.800         0       1   2007.94500
# 1337   61    0  29.070         0       0  29141.36030
#
# [1338 rows x 6 columns]

# %%
sns.scatterplot(x=df['age'],y=df['bmi'],hue=df['sex'])
# Out:
# <Axes: xlabel='age', ylabel='bmi'>

# %%
import seaborn as sns

# %%
df
# Out:
#       age  sex     bmi  children  smoker      charges
# 0      19    0  27.900         0       0  16884.92400
# 1      18    1  33.770         1       1   1725.55230
# 2      28    1  33.000         3       1   4449.46200
# 3      33    1  22.705         0       1  21984.47061
# 4      32    1  28.880         0       1   3866.85520
# ...   ...  ...     ...       ...     ...          ...
# 1333   50    1  30.970         3       1  10600.54830
# 1334   18    0  31.920         0       1   2205.98080
# 1335   18    0  36.850         0       1   1629.83350
# 1336   21    0  25.800         0       1   2007.94500
# 1337   61    0  29.070         0       0  29141.36030
#
# [1338 rows x 6 columns]

# %%
sns.scatterplot(x=df['age'],y=df['charges'],hue=df['sex'])
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
#descriptive analysis
#as per above graph we notice that charges are mostly dense around 0 to 10000 range irrespective of sex of the person.
#we do notice that age does not have a major deciding factor in charges as per the graph.
#charges does not affect charges much as there are people with more than 30 bmi and less with same charges less than 200000.

# %%
df
# Out:
#       age  sex     bmi  children  smoker      charges
# 0      19    0  27.900         0       0  16884.92400
# 1      18    1  33.770         1       1   1725.55230
# 2      28    1  33.000         3       1   4449.46200
# 3      33    1  22.705         0       1  21984.47061
# 4      32    1  28.880         0       1   3866.85520
# ...   ...  ...     ...       ...     ...          ...
# 1333   50    1  30.970         3       1  10600.54830
# 1334   18    0  31.920         0       1   2205.98080
# 1335   18    0  36.850         0       1   1629.83350
# 1336   21    0  25.800         0       1   2007.94500
# 1337   61    0  29.070         0       0  29141.36030
#
# [1338 rows x 6 columns]

# %%
sns.scatterplot(x=df['bmi'],y=df['charges'],hue=df['sex'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
df
# Out:
#       age  sex     bmi  children  smoker      charges
# 0      19    0  27.900         0       0  16884.92400
# 1      18    1  33.770         1       1   1725.55230
# 2      28    1  33.000         3       1   4449.46200
# 3      33    1  22.705         0       1  21984.47061
# 4      32    1  28.880         0       1   3866.85520
# ...   ...  ...     ...       ...     ...          ...
# 1333   50    1  30.970         3       1  10600.54830
# 1334   18    0  31.920         0       1   2205.98080
# 1335   18    0  36.850         0       1   1629.83350
# 1336   21    0  25.800         0       1   2007.94500
# 1337   61    0  29.070         0       0  29141.36030
#
# [1338 rows x 6 columns]

# %%
sns.scatterplot(x=df['bmi'],y=df['charges'],hue=df['children'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(x=df['children'],y=df['charges'],hue=df['sex'])
# Out:
# <Axes: xlabel='children', ylabel='charges'>

# %%
#Diagonstic analysis
#We can find that charges go up based on a adult person and charges irrespective of smoker and children.
#We can find that irrespective of bmi charges do not fluctate much but we do find that charges increase irrespective of gender, age and number of children.

# %%
#Predictive analysis

# %%
#dummy data-no
#input and output-yes

# %%
df
# Out:
#       age  sex     bmi  children  smoker      charges
# 0      19    0  27.900         0       0  16884.92400
# 1      18    1  33.770         1       1   1725.55230
# 2      28    1  33.000         3       1   4449.46200
# 3      33    1  22.705         0       1  21984.47061
# 4      32    1  28.880         0       1   3866.85520
# ...   ...  ...     ...       ...     ...          ...
# 1333   50    1  30.970         3       1  10600.54830
# 1334   18    0  31.920         0       1   2205.98080
# 1335   18    0  36.850         0       1   1629.83350
# 1336   21    0  25.800         0       1   2007.94500
# 1337   61    0  29.070         0       0  29141.36030
#
# [1338 rows x 6 columns]

# %%
X=df.drop(columns=['charges'])

# %%
X
# Out:
#       age  sex     bmi  children  smoker
# 0      19    0  27.900         0       0
# 1      18    1  33.770         1       1
# 2      28    1  33.000         3       1
# 3      33    1  22.705         0       1
# 4      32    1  28.880         0       1
# ...   ...  ...     ...       ...     ...
# 1333   50    1  30.970         3       1
# 1334   18    0  31.920         0       1
# 1335   18    0  36.850         0       1
# 1336   21    0  25.800         0       1
# 1337   61    0  29.070         0       0
#
# [1338 rows x 5 columns]

# %%
Y=df['charges']

# %%
Y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
#scaling is mandatory on k nearest

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit_transform(X)
# Out:
# array([[-1.43876426, -1.0105187 , -0.45332   , -0.90861367, -1.97058663],
#        [-1.50996545,  0.98959079,  0.5096211 , -0.07876719,  0.5074631 ],
#        [-0.79795355,  0.98959079,  0.38330685,  1.58092576,  0.5074631 ],
#        ...,
#        [-1.50996545, -1.0105187 ,  1.0148781 , -0.90861367,  0.5074631 ],
#        [-1.29636188, -1.0105187 , -0.79781341, -0.90861367,  0.5074631 ],
#        [ 1.55168573, -1.0105187 , -0.26138796, -0.90861367, -1.97058663]])

# %%
X
# Out:
#       age  sex     bmi  children  smoker
# 0      19    0  27.900         0       0
# 1      18    1  33.770         1       1
# 2      28    1  33.000         3       1
# 3      33    1  22.705         0       1
# 4      32    1  28.880         0       1
# ...   ...  ...     ...       ...     ...
# 1333   50    1  30.970         3       1
# 1334   18    0  31.920         0       1
# 1335   18    0  36.850         0       1
# 1336   21    0  25.800         0       1
# 1337   61    0  29.070         0       0
#
# [1338 rows x 5 columns]

# %%
X=pd.DataFrame(scaler.fit_transform(X),columns=X.columns)

# %%
X
# Out:
#            age       sex       bmi  children    smoker
# 0    -1.438764 -1.010519 -0.453320 -0.908614 -1.970587
# 1    -1.509965  0.989591  0.509621 -0.078767  0.507463
# 2    -0.797954  0.989591  0.383307  1.580926  0.507463
# 3    -0.441948  0.989591 -1.305531 -0.908614  0.507463
# 4    -0.513149  0.989591 -0.292556 -0.908614  0.507463
# ...        ...       ...       ...       ...       ...
# 1333  0.768473  0.989591  0.050297  1.580926  0.507463
# 1334 -1.509965 -1.010519  0.206139 -0.908614  0.507463
# 1335 -1.509965 -1.010519  1.014878 -0.908614  0.507463
# 1336 -1.296362 -1.010519 -0.797813 -0.908614  0.507463
# 1337  1.551686 -1.010519 -0.261388 -0.908614 -1.970587
#
# [1338 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knr=KNeighborsRegressor(n_neighbors=13)

# %%
knr.fit(X_train,Y_train)
# Out:
# KNeighborsRegressor(n_neighbors=13)

# %%
knr.score(X_test,Y_test)
# Out:
# 0.8317150947659913

# %%
#Prescriptive analysis
#We can find that charges go up based on a adult person and charges irrespective of smoker and children.
#We can find that irrespective of bmi charges do not fluctate much but we do find that charges increase irrespective of gender, age and number of children.
