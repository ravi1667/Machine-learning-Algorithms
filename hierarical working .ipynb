# %%
import pandas as pd

# %%
df=pd.read_csv('country.csv')

# %%
df
# Out:
#                  country  child_mort  exports  health  imports  income
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610  \
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# ...

# %%
df=pd.get_dummies(df)

# %%
df
# Out:
#      child_mort  exports  health  imports  income  inflation  life_expec
# 0          90.2     10.0    7.58     44.9    1610       9.44        56.2  \
# 1          16.6     28.0    6.55     48.6    9930       4.49        76.3
# 2          27.3     38.4    4.17     31.4   12900      16.10        76.5
# 3         119.0     62.3    2.85     42.9    5900      22.40        60.1
# 4          10.3     45.5    6.03     58.9   19100       1.44        76.8
# ..          ...      ...     ...      ...     ...        ...         ...
# 162        29.2     46.6    5.25     52.7    2950       2.62        63.0
# 163        17.1     28.5    4.91     17.6   16500      45.90        75.4
# 164        23.3     72.0    6.84     80.2    4490      12.10        73.1
# 165        56.3     30.0    5.18     34.4    4480      23.60        67.5
# 166        83.1     37.0    5.89     30.9    3280      14.00        52.0
#
#      total_fer   gdpp  country_Afghanistan  ...  country_United Arab Emirates
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X=pd.DataFrame(scaler.fit_transform(df),columns=df.columns)

# %%
X
# Out:
#      child_mort   exports    health   imports    income  inflation
# 0      1.291532 -1.138280  0.279088 -0.082455 -0.808245   0.157336  \
# 1     -0.538949 -0.479658 -0.097016  0.070837 -0.375369  -0.312347
# 2     -0.272833 -0.099122 -0.966073 -0.641762 -0.220844   0.789274
# 3      2.007808  0.775381 -1.448071 -0.165315 -0.585043   1.387054
# 4     -0.695634  0.160668 -0.286894  0.497568  0.101732  -0.601749
# ..          ...       ...       ...       ...       ...        ...
# 162   -0.225578  0.200917 -0.571711  0.240700 -0.738527  -0.489784
# 163   -0.526514 -0.461363 -0.695862 -1.213499 -0.033542   3.616865
# 164   -0.372315  1.130305  0.008877  1.380030 -0.658404   0.409732
# 165    0.448417 -0.406478 -0.597272 -0.517472 -0.658924   1.500916
# 166    1.114951 -0.150348 -0.338015 -0.662477 -0.721358   0.590015
#
#      life_expec  total_fer      gdpp  country_Afghanistan  ...
# 0     -1.619092   1.902882 -0.679180            12.884099  ...  \
# ...

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
mymodel=AgglomerativeClustering(n_clusters=None,distance_threshold=11.309982532964012)

# %%
mymodel.fit(X)
# Out:
# AgglomerativeClustering(distance_threshold=11.309982532964012, n_clusters=None)

# %%
cluster=mymodel.fit_predict(X)

# %%
cluster
# Out:
# array([118, 160, 100, 141, 140, 155, 156, 130, 150,  92, 104,  95, 146,
#        148, 106, 136, 126, 135, 108, 129, 157, 109,  89, 147, 164, 113,
#        123, 144, 124, 158, 145,  85, 131, 101, 139, 137, 110,  97, 117,
#         86, 127, 166, 134, 154, 112, 142, 120, 111,  83, 163,  93, 153,
#         87, 159, 133, 105,  77, 119, 149, 102, 162, 128, 161,  91,  59,
#         70,  63, 151, 122,  79, 107, 132,  66,  64,  69, 165, 143,  88,
#         72, 138, 125,  90,  78, 115,  99,  44,  94,  73,  55, 114,  43,
#         71,  68,  38,  74,  96,  58,  84, 103,  54,  80,  62,  51,  45,
#         52,  56,  67, 121,  35, 116, 152,  81,  98,  47,  31,  61,  39,
#         65,  75,  48,  27,  30,  53,  60,  57,  36,  46,  29,  76,  82,
#         40,  37,  34,  49,  50,  42,  24,  32,  23,  26,  25,  19,  11,
#         15,  21,  41,  18,  22,  12,  10,  28,  33,  14,  17,  16,  13,
#          7,   5,   8,  20,   3,   9,   6,   4,   1,   2,   0], dtype=int64)

# %%
mymodel.children_
# Out:
# array([[ 41, 121],
#        [ 75, 139],
#        [ 24,  85],
#        [111, 158],
#        [ 60, 122],
#        [100, 169],
#        [  1,  48],
#        [ 53, 144],
#        [ 29,  54],
#        [ 20, 130],
#        [  6,  76],
#        [ 56, 129],
#        [ 43, 135],
#        [ 51,  90],
#        [118, 152],
#        [ 67, 134],
#        [  8,  58],
#        [ 94, 166],
#        [ 13, 167],
#        [ 23,  82],
#        [ 12,  69],
#        [ 30, 141],
#        [ 27,  52],
#        [153, 160],
#        [ 65,  83],
#        [ 45,  62],
#        [  4,  86],
#        [ 34, 119],
#        [ 92, 172],
#        [ 35, 190],
#        [ 15, 110],
#        [ 17,  28],
#        [ 42, 138],
#        [168, 170],
#        [ 71, 125],
#        [ 32,  97],
#        [  7,  77],
#        [ 19, 120],
#        [ 61, 173],
#        [ 40, 106],
#        [ 16, 181],
#        [ 80,  93],
#        [115, 128],
#        [162, 189],
#        [ 68, 174],
#        [127, 151],
#        [ 46, 192],
# ...

# %%
from scipy.cluster import hierarchy

# %%
d=hierarchy.linkage(mymodel.children_)

# %%
d
# Out:
# array([[ 10.        ,  36.        ,   1.41421356,   2.        ],
#        [136.        , 143.        ,   1.41421356,   2.        ],
#        [150.        , 156.        ,   2.23606798,   2.        ],
#        [158.        , 160.        ,   2.23606798,   2.        ],
#        [159.        , 169.        ,   2.23606798,   3.        ],
#        [  8.        ,  22.        ,   2.82842712,   2.        ],
#        [ 81.        ,  98.        ,   2.82842712,   2.        ],
#        [163.        , 164.        ,   2.82842712,   2.        ],
#        [ 12.        ,  32.        ,   3.16227766,   2.        ],
#        [  2.        ,  19.        ,   3.16227766,   2.        ],
#        [108.        , 118.        ,   3.16227766,   2.        ],
#        [  3.        ,  50.        ,   3.60555128,   2.        ],
#        [ 83.        , 172.        ,   3.60555128,   3.        ],
#        [119.        , 128.        ,   3.60555128,   2.        ],
# ...

# %%
data=pd.DataFrame(d,columns=['one cluster','Another cluster','Distance','no of data points'])

# %%
data
# Out:
#      one cluster  Another cluster   Distance  no of data points
# 0           10.0             36.0   1.414214                2.0
# 1          136.0            143.0   1.414214                2.0
# 2          150.0            156.0   2.236068                2.0
# 3          158.0            160.0   2.236068                2.0
# 4          159.0            169.0   2.236068                3.0
# ..           ...              ...        ...                ...
# 160        267.0            325.0  27.166155              155.0
# 161        320.0            324.0  27.802878                9.0
# 162        130.0            326.0  28.178006              156.0
# 163        146.0            327.0  30.886890               10.0
# 164        328.0            329.0  34.655447              166.0
#
# [165 rows x 4 columns]

# %%
data['Distance'].mean()
# Out:
# 11.309982532964012

# %%
mymodel=AgglomerativeClustering(n_clusters=None,distance_threshold=11.309982532964012)

# %%
cluster=mymodel.fit_predict(X)

# %%
cluster
# Out:
# array([118, 160, 100, 141, 140, 155, 156, 130, 150,  92, 104,  95, 146,
#        148, 106, 136, 126, 135, 108, 129, 157, 109,  89, 147, 164, 113,
#        123, 144, 124, 158, 145,  85, 131, 101, 139, 137, 110,  97, 117,
#         86, 127, 166, 134, 154, 112, 142, 120, 111,  83, 163,  93, 153,
#         87, 159, 133, 105,  77, 119, 149, 102, 162, 128, 161,  91,  59,
#         70,  63, 151, 122,  79, 107, 132,  66,  64,  69, 165, 143,  88,
#         72, 138, 125,  90,  78, 115,  99,  44,  94,  73,  55, 114,  43,
#         71,  68,  38,  74,  96,  58,  84, 103,  54,  80,  62,  51,  45,
#         52,  56,  67, 121,  35, 116, 152,  81,  98,  47,  31,  61,  39,
#         65,  75,  48,  27,  30,  53,  60,  57,  36,  46,  29,  76,  82,
#         40,  37,  34,  49,  50,  42,  24,  32,  23,  26,  25,  19,  11,
#         15,  21,  41,  18,  22,  12,  10,  28,  33,  14,  17,  16,  13,
#          7,   5,   8,  20,   3,   9,   6,   4,   1,   2,   0], dtype=int64)

# %%
df=pd.read_csv('country.csv')

# %%
df['cluster label']=cluster

# %%
df
# Out:
#                  country  child_mort  exports  health  imports  income
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610  \
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp  cluster label
# ...

# %%
df.to_csv('countryoutput.csv',index=False)
