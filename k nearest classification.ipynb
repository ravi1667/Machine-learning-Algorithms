# %%
import pandas as pd

# %%
df=pd.read_csv('car.csv')

# %%
df
# Out:
#     Salary  Expenses carornot
# 0    25000     20000       No
# 1    75000     40000      Yes
# 2    34000     30000       No
# 3    29000     25000       No
# 4    31000     20000       No
# 5    33000     31000       No
# 6    52000     26000      Yes
# 7    49000     30000      Yes
# 8    20000     15000       No
# 9    15000     12000       No
# 10   55000     38000      Yes
# 11   49000     33000      Yes
# 12   53000     30000      Yes
# 13   21000     17000       No
# 14   45271     13537      Yes
# 15   75074     18261      Yes
# 16   82582     37160      Yes
# 17   22233     17393       No
# 18   79000     40730      Yes
# 19   28500     22800       No
# 20   19000     18000       No
# 21   74000     20000      Yes
# 22  137000     43000      Yes
# 23   57000     16000      Yes
# 24   76000     44000      Yes
# 25   90000     58000      Yes
# 26   84000     27000      Yes
# 27  150000     28000      Yes
# 28   80000     31000      Yes
# 29   52000     17000      Yes
# ...

# %%
sns.scatterplot(x=df['Salary'],y=df['Expenses'],hue=df['carornot'])
# Out:
# <Axes: xlabel='Salary', ylabel='Expenses'>

# %%
import seaborn as sns

# %%
y=df[df['Salary']>120000].index

# %%
df2=df.drop(index=y,inplace=True)

# %%
df
# Out:
#     Salary  Expenses carornot
# 0    25000     20000       No
# 1    75000     40000      Yes
# 2    34000     30000       No
# 3    29000     25000       No
# 4    31000     20000       No
# 5    33000     31000       No
# 6    52000     26000      Yes
# 7    49000     30000      Yes
# 8    20000     15000       No
# 9    15000     12000       No
# 10   55000     38000      Yes
# 11   49000     33000      Yes
# 12   53000     30000      Yes
# 13   21000     17000       No
# 14   45271     13537      Yes
# 15   75074     18261      Yes
# 16   82582     37160      Yes
# 17   22233     17393       No
# 18   79000     40730      Yes
# 19   28500     22800       No
# 20   19000     18000       No
# 21   74000     20000      Yes
# 23   57000     16000      Yes
# 24   76000     44000      Yes
# 25   90000     58000      Yes
# 26   84000     27000      Yes
# 28   80000     31000      Yes
# 29   52000     17000      Yes
# 30   86000     51000      Yes
# 31  108000     18000      Yes
# ...

# %%
sns.scatterplot(x=df['Salary'],y=df['Expenses'],hue=df['carornot'])
# Out:
# <Axes: xlabel='Salary', ylabel='Expenses'>

# %%
#descriptive analysis
#As per the above graph, we do notice that irrespective of expenses, when salary is above 40,000, they are purchasing a car for sure.
#people below 40,000 are not purchasing a car irrespective of their expenses.

# %%
sns.scatterplot(x=df['Salary'],y=df['Expenses'])
# Out:
# <Axes: xlabel='Salary', ylabel='Expenses'>

# %%
#Diagnostic analysis
#We can provide better loan offers for people less than 40,000 salary to make them purchase a car
#We can also provide better insurance for people above 40,000 salary to make them purchase a car at a higher cost too.
#we do notice that most people expenses are below 35,000 too.

# %%
#Predictive analysis

# %%
df
# Out:
#     Salary  Expenses carornot
# 0    25000     20000       No
# 1    75000     40000      Yes
# 2    34000     30000       No
# 3    29000     25000       No
# 4    31000     20000       No
# 5    33000     31000       No
# 6    52000     26000      Yes
# 7    49000     30000      Yes
# 8    20000     15000       No
# 9    15000     12000       No
# 10   55000     38000      Yes
# 11   49000     33000      Yes
# 12   53000     30000      Yes
# 13   21000     17000       No
# 14   45271     13537      Yes
# 15   75074     18261      Yes
# 16   82582     37160      Yes
# 17   22233     17393       No
# 18   79000     40730      Yes
# 19   28500     22800       No
# 20   19000     18000       No
# 21   74000     20000      Yes
# 23   57000     16000      Yes
# 24   76000     44000      Yes
# 25   90000     58000      Yes
# 26   84000     27000      Yes
# 28   80000     31000      Yes
# 29   52000     17000      Yes
# 30   86000     51000      Yes
# 31  108000     18000      Yes
# ...

# %%
#dummy data
df=pd.get_dummies(df)

# %%
df
# Out:
#     Salary  Expenses  carornot_No  carornot_Yes
# 0    25000     20000         True         False
# 1    75000     40000        False          True
# 2    34000     30000         True         False
# 3    29000     25000         True         False
# 4    31000     20000         True         False
# 5    33000     31000         True         False
# 6    52000     26000        False          True
# 7    49000     30000        False          True
# 8    20000     15000         True         False
# 9    15000     12000         True         False
# 10   55000     38000        False          True
# 11   49000     33000        False          True
# 12   53000     30000        False          True
# 13   21000     17000         True         False
# 14   45271     13537        False          True
# 15   75074     18261        False          True
# 16   82582     37160        False          True
# 17   22233     17393         True         False
# 18   79000     40730        False          True
# ...

# %%
X=df.drop(columns=['carornot_No','carornot_Yes'])

# %%
Y=df['carornot_Yes']

# %%
X
# Out:
#     Salary  Expenses
# 0    25000     20000
# 1    75000     40000
# 2    34000     30000
# 3    29000     25000
# 4    31000     20000
# 5    33000     31000
# 6    52000     26000
# 7    49000     30000
# 8    20000     15000
# 9    15000     12000
# 10   55000     38000
# 11   49000     33000
# 12   53000     30000
# 13   21000     17000
# 14   45271     13537
# 15   75074     18261
# 16   82582     37160
# 17   22233     17393
# 18   79000     40730
# 19   28500     22800
# 20   19000     18000
# 21   74000     20000
# 23   57000     16000
# 24   76000     44000
# 25   90000     58000
# 26   84000     27000
# 28   80000     31000
# 29   52000     17000
# 30   86000     51000
# 31  108000     18000
# 32   82000     15000
# 33   25000     20000
# 34   79000     26000
# 35   54000     28000
# 37   89000     22000
# 38   83000     22000
# 39   23000     23000
# 40   58000     20000
# 41   55000     28000
# 42   48000     30000
# 43   79000     43000
# 44   41000     30000
# ...

# %%
Y
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7      True
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13    False
# 14     True
# 15     True
# 16     True
# 17    False
# 18     True
# 19    False
# 20    False
# 21     True
# 23     True
# 24     True
# 25     True
# 26     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33    False
# 34     True
# 35     True
# 37     True
# 38     True
# 39    False
# 40     True
# 41     True
# 42     True
# 43     True
# 44    False
# 45     True
# 46    False
# Name: carornot_Yes, dtype: bool

# %%
#scaling is mandatory for K nearest

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
pd.DataFrame(scaler.fit_transform(X),columns=X.columns)
# Out:
#       Salary  Expenses
# 0  -1.177601 -0.611115
# 1   0.828130  1.317239
# 2  -0.816570  0.353062
# 3  -1.017143 -0.129027
# 4  -0.936914 -0.611115
# 5  -0.856684  0.449480
# 6  -0.094506 -0.032609
# 7  -0.214850  0.353062
# 8  -1.378175 -1.093204
# 9  -1.578748 -1.382457
# 10  0.025837  1.124404
# 11 -0.214850  0.642315
# 12 -0.054392  0.353062
# 13 -1.338060 -0.900369
# 14 -0.364438 -1.234263
# 15  0.831099 -0.778786
# 16  1.132279  1.043413
# 17 -1.288599 -0.862476
# 18  0.988589  1.387624
# 19 -1.037200 -0.341146
# 20 -1.418289 -0.803951
# 21  0.788015 -0.611115
# 22  0.106067 -0.996786
# 23  0.868245  1.702910
# 24  1.429850  3.052759
# 25  1.189162  0.063809
# 26  1.028703  0.449480
# 27 -0.094506 -0.900369
# 28  1.269391  2.377835
# 29  2.151913 -0.803951
# 30  1.108932 -1.093204
# 31 -1.177601 -0.611115
# 32  0.988589 -0.032609
# 33 -0.014277  0.160227
# 34  1.389735 -0.418280
# 35  1.149047 -0.418280
# 36 -1.257831 -0.321862
# 37  0.146181 -0.611115
# 38  0.025837  0.160227
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knc=KNeighborsClassifier(n_neighbors=4)

# %%
knc.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
knc.score(X_test,Y_test)
# Out:
# 1.0

# %%
#Prescriptive analysis
#Kindly provide more importance to people above 40,000 salary and below for new oppurtunities.
